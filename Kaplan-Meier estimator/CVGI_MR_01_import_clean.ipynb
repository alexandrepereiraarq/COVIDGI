# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from math import floor
from random import sample
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

sns.set(color_codes=True)

# %% [markdown]
# Calling the functions file

# %%
# %run ./CVGI_MR_00_functions.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# initiating

# %%
imports()
# Out:
# What is the source of the MOVEMENT data? (1=internet, 2=home Mac, 3=office Windows) 2
# What type of import is it? (1 = initial (only cases and movement), 2 = initial (full), 3 = data by week, 4 = merged datasets, 5 = only cases) 1
# ../../../02 data
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6533090 entries, 0 to 6533089
# Data columns (total 9 columns):
#  #   Column                                      Dtype
# ---  ------                                      -----
#  0   ds                                          datetime64[ns]
#  1   country                                     object
#  2   polygon_source                              object
#  3   polygon_id                                  object
#  4   polygon_name                                object
#  5   all_day_bing_tiles_visited_relative_change  float64
#  6   all_day_ratio_single_tile_users             float64
#  7   baseline_name                               object
# ...

# %% [markdown]
# ---

# %% [markdown]
# <h4> Preparation of initial data </h4>
# Prepares datasets to group data by epidemiological week.

# %%
drops()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1191144 entries, 416072 to 1607215
# Data columns (total 6 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   date             1191144 non-null  datetime64[ns]
#  1   country          1191144 non-null  object
#  2   GADM_GID_2       1191144 non-null  object
#  3   mun_name         1191144 non-null  object
#  4   movement_change  1191144 non-null  float64
#  5   stay_put         1191144 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 63.6+ MB
#
# ...
# +++++++++++++++++++++++++Movement Range, dropped+++++++++++++++++++++++++
# ...
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2123295 entries, 0 to 2135150
# Data columns (total 11 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   mun_name              object
#  1   ibge_code             object
#  2   date                  datetime64[ns]
# ...

# %% [markdown]
# ---

# %%
cases
# Out:
#              mun_name ibge_code       date  epidemiological_week  pop_2019  \
# 0          Rio Branco   1200401 2020-03-17                202012  407319.0
# 2          Rio Branco   1200401 2020-03-18                202012  407319.0
# 4          Rio Branco   1200401 2020-03-19                202012  407319.0
# 6          Rio Branco   1200401 2020-03-20                202012  407319.0
# 8          Rio Branco   1200401 2020-03-21                202012  407319.0
# ...               ...       ...        ...                   ...       ...
# 2135146    Tocantínia   1721109 2021-05-25                202121    7545.0
# 2135147      Tupirama   1721257 2021-05-25                202121    1891.0
# 2135148    Tupiratins   1721307 2021-05-25                202121    2671.0
# 2135149  Wanderlândia   1722081 2021-05-25                202121   11683.0
# 2135150       Xambioá   1722107 2021-05-25                202121   11540.0
#
# ...

# %%
cases.drop('epi_week', axis=1, inplace=True)

# %%
randSample = sorted(sample(range(2123295),k=55))
# %run ./CVGI_MR_00_functions.ipynb

# %%
rows = randSample
cases = new_columns(cases,['epi_week'])
    #print(rows)    
for i in range(len(cases.iloc[1:100])):
    week_txt = right(str(cases.epidemiological_week.iloc[i]),2) #Brasil.io always codes "epidemiological_week" with 6 digits
    year_txt = left(str(cases.epidemiological_week.iloc[i]),4)
    cases.epi_week.iloc[i] = year_txt + "." + week_txt
cases.iloc[1:100]
# Out:
#               mun_name ibge_code       date  epidemiological_week  pop_2019  \
# 2           Rio Branco   1200401 2020-03-18                202012  407319.0
# 4           Rio Branco   1200401 2020-03-19                202012  407319.0
# 6           Rio Branco   1200401 2020-03-20                202012  407319.0
# 8           Rio Branco   1200401 2020-03-21                202012  407319.0
# 10          Rio Branco   1200401 2020-03-22                202013  407319.0
# ..                 ...       ...        ...                   ...       ...
# 126    Cruzeiro do Sul   1200203 2020-04-17                202016   88376.0
# 127  Plácido de Castro   1200385 2020-04-17                202016   19761.0
# 128         Porto Acre   1200807 2020-04-17                202016   18504.0
# 129         Rio Branco   1200401 2020-04-17                202016  407319.0
# 131         Acrelândia   1200013 2020-04-18                202016   15256.0
#
# ...

# %%
cases_week = cases_cleanup(None,True,False)

# %%
cases_week.head()
# Out:
#                     new_confirmed  new_deaths  acc_cases  acc_deaths  \
# ibge_code epi_week
# 1100015   n                  3640          61     510470        7012
# 1100023   n                 19608         427    2954606       55358
# 1100031   n                   680          18      89291        2438
# 1100049   n                 11991         236    1629546       25312
# 1100056   n                  2199          55     231936        5005
#
#                     pop_2019 epi_week_col  acc_cases_100k  acc_deaths_1mi
# ibge_code epi_week
# 1100015   n          22945.0            n      2224754.85       305600.35
# 1100023   n         107863.0            n      2739221.05       513225.11
# 1100031   n           5312.0            n      1680929.97       458960.84
# 1100049   n          85359.0            n      1909050.01       296535.81
# 1100056   n          16323.0            n      1420915.27       306622.56

# %%
cases.date.min()
# Out:
# Timestamp('2020-02-25 00:00:00')

# %%
cases.date.max()
# Out:
# Timestamp('2021-05-25 00:00:00')

# %%
cases[cases.date == "2021-01-01"]
# Out:
#              mun_name ibge_code       date  epidemiological_week  pop_2019  \
# 5777       Acrelândia   1200013 2021-01-01                202053   15256.0
# 5778     Assis Brasil   1200054 2021-01-01                202053    7417.0
# 5779        Brasiléia   1200104 2021-01-01                202053   26278.0
# 5780           Bujari   1200138 2021-01-01                202053   10266.0
# 5781         Capixaba   1200179 2021-01-01                202053   11733.0
# ...               ...       ...        ...                   ...       ...
# 2114986    Tocantínia   1721109 2021-01-01                202053    7545.0
# 2114987      Tupirama   1721257 2021-01-01                202053    1891.0
# 2114988    Tupiratins   1721307 2021-01-01                202053    2671.0
# 2114989  Wanderlândia   1722081 2021-01-01                202053   11683.0
# 2114990       Xambioá   1722107 2021-01-01                202053   11540.0
#
# ...
